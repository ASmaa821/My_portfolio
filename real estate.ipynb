# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('uae_properties.csv')

# %%
df.head()
# Out:
#          id                                              title  \
# 0  10837871  ★ EXCLUSIVE RELEASE ★ | LUXURY 3 BED FLAT | GO...
# 1  10880180  ★ BUY NOW 624,000AED ★ (20% FIRST PAYMENT + 4%...
# 2  11220200  GREEN HEART OF DUBAI |URBAN DESIGN | LUXURY LI...
# 3  11176502  Prime Location | Corner Spacious Unit | Bright...
# 4  11179908  Very Limited | Ideal For Investment | 40% Disc...
#
#                                       displayAddress  bathrooms  bedrooms  \
# 0  Sobha One, Sobha Hartland, Mohammed Bin Rashid...          2         3
# 1           Sobha Verde, Jumeirah Lake Towers, Dubai          2         3
# 2            Park Horizon, Dubai Hills Estate, Dubai          2         3
# 3           AZIZI Riviera, Meydan One, Meydan, Dubai          2         3
# 4              Verdana, Dubai Investment Park, Dubai          2         0
#
#                      addedOn type           rera propertyType    price
# 0  2024-01-06T17:05:24+00:00  buy    817,185,656    apartment  3950000
# 1  2024-01-13T21:19:31+00:00  buy    817,185,656    apartment  2600000
# 2  2024-03-12T03:18:54+00:00  buy  2,125,965,775    apartment  3450000
# 3  2024-03-04T06:53:51+00:00  buy 71,149,777,382    apartment  2000000
# 4  2024-03-04T13:24:39+00:00  buy    465,261,649    apartment   284000

# %%
df['price'] = df['price'].astype(int)
df['rera']=df['rera'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              492 non-null    int64
#  1   title           492 non-null    object
#  2   displayAddress  492 non-null    object
#  3   bathrooms       492 non-null    int64
#  4   bedrooms        492 non-null    int64
#  5   addedOn         492 non-null    object
#  6   type            492 non-null    object
#  7   rera            323 non-null    float64
#  8   propertyType    492 non-null    object
#  9   price           492 non-null    int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 38.6+ KB

# %%
df.describe()
# Out:
#               id  bathrooms  bedrooms            rera      price
# count        492        492       492             323        492
# mean  10,897,777          2         2  15,629,275,949  2,166,491
# std      389,056          0         1  28,430,120,260  2,126,998
# min    8,741,796          2         0       8,470,901    233,000
# 25%   10,749,757          2         0     818,620,866    952,964
# 50%   11,040,520          2         3   1,678,337,573  1,499,000
# 75%   11,179,562          2         3   7,131,427,186  2,434,250
# max   11,250,451          2         3 202,202,794,105 14,500,000

# %%
df.columns
# Out:
# Index(['id', 'title', 'displayAddress', 'bathrooms', 'bedrooms', 'addedOn',
#        'type', 'rera', 'propertyType', 'price'],
#       dtype='object')

# %%
df['city'] = df['displayAddress'].str.split(',').str[-1]
# Extract city from the last part of displayAddress

# %%
df
# Out:
#            id                                              title  \
# 0    10837871  ★ EXCLUSIVE RELEASE ★ | LUXURY 3 BED FLAT | GO...
# 1    10880180  ★ BUY NOW 624,000AED ★ (20% FIRST PAYMENT + 4%...
# 2    11220200  GREEN HEART OF DUBAI |URBAN DESIGN | LUXURY LI...
# 3    11176502  Prime Location | Corner Spacious Unit | Bright...
# 4    11179908  Very Limited | Ideal For Investment | 40% Disc...
# ..        ...                                                ...
# 487  11221319    Best Offer | Limited 3 Bed | Furnished Serviced
# 488  10837884  LUXURY FLAT | GOLDEN VISA | GREAT VIEW | FLEXI...
# 489  11134630                  Magnificent| Luxurious l High ROI
# 490  11151144   Full Burj Khalifa  | High Floor | Confirm Seller
# 491  10615925        Invest in this Modern Unit For Your Family!
#
#                                         displayAddress  bathrooms  bedrooms  \
# 0    Sobha One, Sobha Hartland, Mohammed Bin Rashid...          2         3
# 1             Sobha Verde, Jumeirah Lake Towers, Dubai          2         3
# 2              Park Horizon, Dubai Hills Estate, Dubai          2         3
# 3             AZIZI Riviera, Meydan One, Meydan, Dubai          2         3
# 4                Verdana, Dubai Investment Park, Dubai          2         0
# ..                                                 ...        ...       ...
# 487  North 43 Residences, Jumeirah Village Circle, ...          2         3
# 488           Sobha Verde, Jumeirah Lake Towers, Dubai          2         3
# 489  310 Riverside Crescent, Sobha Hartland II, Moh...          2         3
# 490             Boulevard Point, Downtown Dubai, Dubai          2         3
# 491              Ansam 1, Ansam, Yas Island, Abu Dhabi          2         0
#
#                        addedOn type           rera propertyType    price  \
# 0    2024-01-06T17:05:24+00:00  buy    817,185,656    apartment  3950000
# 1    2024-01-13T21:19:31+00:00  buy    817,185,656    apartment  2600000
# 2    2024-03-12T03:18:54+00:00  buy  2,125,965,775    apartment  3450000
# 3    2024-03-04T06:53:51+00:00  buy 71,149,777,382    apartment  2000000
# 4    2024-03-04T13:24:39+00:00  buy    465,261,649    apartment   284000
# ..                         ...  ...            ...          ...      ...
# 487  2024-03-12T08:31:25+00:00  buy    456,027,703    apartment  1914927
# 488  2024-01-06T17:09:49+00:00  buy    817,185,656    apartment  2650000
# 489  2024-02-26T06:31:21+00:00  buy    173,353,897    apartment  2191944
# 490  2024-02-28T07:11:49+00:00  buy  6,512,527,887    apartment  6600000
# 491  2023-11-22T09:40:55+00:00  buy            NaN    apartment   850000
#
#            city
# 0         Dubai
# 1         Dubai
# 2         Dubai
# 3         Dubai
# 4         Dubai
# ..          ...
# 487       Dubai
# 488       Dubai
# 489       Dubai
# 490       Dubai
# 491   Abu Dhabi
#
# [492 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 492 entries, 0 to 491
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              492 non-null    int64
#  1   title           492 non-null    object
#  2   displayAddress  492 non-null    object
#  3   bathrooms       492 non-null    int64
#  4   bedrooms        492 non-null    int64
#  5   addedOn         492 non-null    object
#  6   type            492 non-null    object
#  7   rera            323 non-null    float64
#  8   propertyType    492 non-null    object
#  9   price           492 non-null    int64
#  10  city            492 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 42.4+ KB

# %%
# pd.options.display.float_format = '{:,.0f}'.format
df.groupby('bedrooms')['price'].mean()
# Out:
# bedrooms
# 0     783,540
# 3   2,722,036
# Name: price, dtype: float64

# %%
table=pd.pivot_table(df,values='price',index='city',columns='bedrooms',aggfunc=['mean' , 'max' , 'sum' , 'min'])
table
# Out:
#                   mean                max                 sum             \
# bedrooms             0         3        0         3         0          3
# city
# Abu Dhabi      613,292 1,506,988   910000  11000000   7972800  164261744
# Ajman          233,000   347,800   233000    699000    233000    1739000
# Dubai          845,891 3,559,830  3920000  14500000  93048026  701286531
# Ras Al Khaimah 916,670 3,329,948  1300010   5242928   2750010   36629427
# Sharjah        462,518 1,776,483   499000   2608000   6475250   51518000
#
#                    min
# bedrooms             0       3
# city
# Abu Dhabi       320000  850000
# Ajman           233000  245000
# Dubai           248000  899990
# Ras Al Khaimah  530000  399999
# Sharjah         330000  650000

# %%
# pd.options.display.float_format = '{:,.0f}'.format
df.groupby('bathrooms')['price'].mean()
# Out:
# bathrooms
# 2   2,166,491
# Name: price, dtype: float64

# %%
df.groupby(['city', 'bedrooms']).agg(
    number_of_properties=('city', 'count'),
    total_price=('price', 'sum')
)
# Out:
#                          number_of_properties  total_price
# city           bedrooms
# Abu Dhabi      0                           13      7972800
#                3                          109    164261744
# Ajman          0                            1       233000
#                3                            5      1739000
# Dubai          0                          110     93048026
#                3                          197    701286531
# Ras Al Khaimah 0                            3      2750010
#                3                           11     36629427
# Sharjah        0                           14      6475250
#                3                           29     51518000

# %%
df[['price', 'bedrooms', 'bathrooms']].corr()
##"The dataset shows that all properties have 2 bathrooms. As a result, bathrooms do
##not contribute to the variation in property prices, and correlation with price cannot be computed."
# Out:
#            price  bedrooms  bathrooms
# price          1         0        NaN
# bedrooms       0         1        NaN
# bathrooms    NaN       NaN        NaN

# %%
df['area']=df['displayAddress'].str.split(',').str[-2]

# %%
df.groupby('area')['price'].mean().sort_values(ascending=False).head(10)
# Out:
# area
# Bluewaters                 14,500,000
# Saadiyat Island            11,000,000
# Palm Jumeirah               9,132,567
# Umm Suqeim                  7,500,000
# City Walk                   6,700,000
# Dubai Harbour               6,522,178
# Jumeirah Beach Residence    6,133,333
# Downtown Dubai              5,635,597
# Emirates Hills 2            4,715,000
# Dubai Marina                4,599,864
# Name: price, dtype: float64

# %%
df.groupby('area').agg(
    number_of_properties=('area', 'count'),
    total_price=('price', 'sum')
).sort_values('total_price', ascending=False).head(10)
# Out:
#                           number_of_properties  total_price
# area
# Business Bay                                24     95916413
# Downtown Dubai                              17     95805154
# Jumeirah Village Circle                     45     65039094
# Palm Jumeirah                                6     54795400
# Al Shamkha                                  43     50552999
# Al Reem Island                              35     49857299
# Dubai Marina                                10     45998644
# Yas Island                                  24     41076246
# Jumeirah Beach Residence                     6     36799999
# Jumeirah Lake Towers                        17     33010000

# %%
bins = [0, 500000, 1000000, 2000000, 5000000, 10000000]
labels = ['<500k','500k-1M','1M-2M','2M-5M','>5M']
df['price_range'] = pd.cut(df['price'], bins=bins, labels=labels)

# %%
df
# Out:
#            id                                              title  \
# 0    10837871  ★ EXCLUSIVE RELEASE ★ | LUXURY 3 BED FLAT | GO...
# 1    10880180  ★ BUY NOW 624,000AED ★ (20% FIRST PAYMENT + 4%...
# 2    11220200  GREEN HEART OF DUBAI |URBAN DESIGN | LUXURY LI...
# 3    11176502  Prime Location | Corner Spacious Unit | Bright...
# 4    11179908  Very Limited | Ideal For Investment | 40% Disc...
# ..        ...                                                ...
# 487  11221319    Best Offer | Limited 3 Bed | Furnished Serviced
# 488  10837884  LUXURY FLAT | GOLDEN VISA | GREAT VIEW | FLEXI...
# 489  11134630                  Magnificent| Luxurious l High ROI
# 490  11151144   Full Burj Khalifa  | High Floor | Confirm Seller
# 491  10615925        Invest in this Modern Unit For Your Family!
#
#                                         displayAddress  bathrooms  bedrooms  \
# 0    Sobha One, Sobha Hartland, Mohammed Bin Rashid...          2         3
# 1             Sobha Verde, Jumeirah Lake Towers, Dubai          2         3
# 2              Park Horizon, Dubai Hills Estate, Dubai          2         3
# 3             AZIZI Riviera, Meydan One, Meydan, Dubai          2         3
# 4                Verdana, Dubai Investment Park, Dubai          2         0
# ..                                                 ...        ...       ...
# 487  North 43 Residences, Jumeirah Village Circle, ...          2         3
# 488           Sobha Verde, Jumeirah Lake Towers, Dubai          2         3
# 489  310 Riverside Crescent, Sobha Hartland II, Moh...          2         3
# 490             Boulevard Point, Downtown Dubai, Dubai          2         3
# 491              Ansam 1, Ansam, Yas Island, Abu Dhabi          2         0
#
#                        addedOn type           rera propertyType    price  \
# 0    2024-01-06T17:05:24+00:00  buy    817,185,656    apartment  3950000
# 1    2024-01-13T21:19:31+00:00  buy    817,185,656    apartment  2600000
# 2    2024-03-12T03:18:54+00:00  buy  2,125,965,775    apartment  3450000
# 3    2024-03-04T06:53:51+00:00  buy 71,149,777,382    apartment  2000000
# 4    2024-03-04T13:24:39+00:00  buy    465,261,649    apartment   284000
# ..                         ...  ...            ...          ...      ...
# 487  2024-03-12T08:31:25+00:00  buy    456,027,703    apartment  1914927
# 488  2024-01-06T17:09:49+00:00  buy    817,185,656    apartment  2650000
# 489  2024-02-26T06:31:21+00:00  buy    173,353,897    apartment  2191944
# 490  2024-02-28T07:11:49+00:00  buy  6,512,527,887    apartment  6600000
# 491  2023-11-22T09:40:55+00:00  buy            NaN    apartment   850000
#
#            city                       area price_range
# 0         Dubai   Mohammed Bin Rashid City       2M-5M
# 1         Dubai       Jumeirah Lake Towers       2M-5M
# 2         Dubai         Dubai Hills Estate       2M-5M
# 3         Dubai                     Meydan       1M-2M
# 4         Dubai      Dubai Investment Park       <500k
# ..          ...                        ...         ...
# 487       Dubai    Jumeirah Village Circle       1M-2M
# 488       Dubai       Jumeirah Lake Towers       2M-5M
# 489       Dubai   Mohammed Bin Rashid City       2M-5M
# 490       Dubai             Downtown Dubai         >5M
# 491   Abu Dhabi                 Yas Island     500k-1M
#
# [492 rows x 13 columns]

# %%
price_city = pd.crosstab(df['city'], df['price_range'])
price_city
# Out:
# price_range     <500k  500k-1M  1M-2M  2M-5M  >5M
# city
# Abu Dhabi           5       10     97      9    0
# Ajman               5        1      0      0    0
# Dubai              16       72     83     98   31
# Ras Al Khaimah      1        2      3      7    1
# Sharjah            14        2     16     11    0

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='city', y='price', data=df)
plt.title('Price Distribution per City')
plt.xlabel('City')
plt.ylabel('Price (AED)')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(city_bedrooms_price, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Average Price per City and Bedrooms")
plt.xlabel("Bedrooms")
plt.ylabel("City")
plt.show()

# %%
top_areas = df.groupby('area')['price'].sum().sort_values(ascending=False).head(10)
top_areas.plot(kind='bar', figsize=(10,6), color='orange')
plt.title('Top 10 Areas by Total Property Value')
plt.xlabel('Area')
plt.ylabel('Total Price (AED)')
plt.show()

# %%
price_city.plot(kind='bar', stacked=True, figsize=(10,6), colormap='viridis')
plt.title("Properties per City by Price Range")
plt.xlabel("City")
plt.ylabel("Number of Properties")
plt.show()

# %%
bedrooms_city = pd.crosstab(df['city'], df['bedrooms'])
bedrooms_city.plot(kind='bar', stacked=True, figsize=(10,6), colormap='coolwarm')
plt.title("Distribution of Bedrooms per City")
plt.xlabel("City")
plt.ylabel("Number of Properties")
plt.show()
