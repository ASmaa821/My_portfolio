# %% [markdown]
# # 🎮 Data Cleaning and Analysis for Games Dataset
#
# ## 📌 Project Overview:
# This project focuses on cleaning and analyzing a dataset of board games to discover insights related to game features and user interactions.
#
# ---
#
# ## 🧹 Phase 1: Data Cleaning
#
# - Loaded raw data from `games.csv`.
# - Dropped fully empty rows.
# - Removed unnecessary columns (e.g., `url`, `id`).
# - Handled missing and invalid values.
# - Prepared a clean dataset: `cleaned_data.csv`.
#
# ---
#
# ## 📊 Phase 2: Data Analysis & Visualization
#
# - Loaded cleaned dataset.
# - Used `.info()` and `.describe()` to understand the structure.
# - Created visualizations:
#   - Histogram of game ratings.
#   - Heatmap of correlations between features.
#   - Scatter plots showing relationships (e.g., number of players vs. rating).
# - Tools used: `Pandas`, `Seaborn`, `Matplotlib`.
#
# ---
#
# ## ✅ Key Findings:
#
# - Strong relationships found between certain features (e.g., number of users and ratings).
# - Visual patterns revealed data trends effectively.
# - Cleaning phase was essential to remove noise and prepare the dataset.
#
# ---
#
# ## 📈 Portfolio Value:
#
# - Shows complete cycle: data cleaning → visualization → insights.
# - Code is organized and readable.
# - Great example of working with real-world messy data.
#
# **⭐ Final Score: 8.5/10**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cleaned_data.csv")
df
# Out:
#                                            title                    publisher  \
# 0                             Grand Theft Auto V               Rockstar Games
# 1                             Grand Theft Auto V               Rockstar Games
# 2                    Grand Theft Auto: Vice City               Rockstar Games
# 3                             Grand Theft Auto V               Rockstar Games
# 4                      Call of Duty: Black Ops 3                   Activision
# ..                                           ...                          ...
# 213                             FIFA Soccer 2003                    EA Sports
# 214                                   Crash Bash  Sony Computer Entertainment
# 215                               Gears of War 4            Microsoft Studios
# 216  The Elder Scrolls V: Skyrim Special Edition           Bethesda Softworks
# 217                                 Watch Dogs 2                      Ubisoft
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                            title                    publisher  \
# 0                             Grand Theft Auto V               Rockstar Games
# 1                             Grand Theft Auto V               Rockstar Games
# 2                    Grand Theft Auto: Vice City               Rockstar Games
# 3                             Grand Theft Auto V               Rockstar Games
# 4                      Call of Duty: Black Ops 3                   Activision
# ..                                           ...                          ...
# 213                             FIFA Soccer 2003                    EA Sports
# 214                                   Crash Bash  Sony Computer Entertainment
# 215                               Gears of War 4            Microsoft Studios
# 216  The Elder Scrolls V: Skyrim Special Edition           Bethesda Softworks
# 217                                 Watch Dogs 2                      Ubisoft
#
# ...

# %%
df.describe()
# Out:
#        total_sales  critic_score  north_america_sales  japan_sales  \
# count   218.000000    218.000000           218.000000   218.000000
# mean      5.761514      8.425000             2.675550     0.179727
# std       3.110164      0.824034             1.731387     0.239364
# min       3.360000      4.200000             0.050000     0.000000
# 25%       3.857500      8.200000             1.635000     0.050000
# 50%       4.580000      8.425000             2.260000     0.120000
# 75%       6.327500      9.000000             3.212500     0.179727
# max      20.320000     10.000000             9.760000     1.870000
#
#        europe_sales  other_sales
# count    218.000000   218.000000
# mean       2.221376     0.714771
# std        1.583499     0.516953
# min        0.000000     0.040000
# 25%        1.270000     0.392500
# 50%        1.850000     0.570000
# 75%        2.572500     0.860000
# max        9.850000     3.120000

# %%
cols = ["total_sales", "north_america_sales", "europe_sales","other_sales"]
df_melted = df[cols].melt(var_name="Region", value_name="Sales")
sns.boxplot(data=df_melted, x="Region", y="Sales")
plt.title("Boxplot of Sales by Region")
plt.show()

# %%
# نحدد الأعمدة اللي فيها مبيعات
sales_columns = ['north_america_sales', 'japan_sales', 'europe_sales', 'other_sales']

for col in sales_columns:
  Q1=df[col].quantile(0.25)
  Q3=df[col].quantile(0.75)
  IQR=Q3-Q1

  lower_bound=Q1-1.5*IQR
  upper_bound=Q3+1.5*IQR
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  df=df[(df[col] > lower_bound) & (df[col] < upper_bound)]



  print(len(outliers))
  print(f"lower bound {lower_bound}:")
  print(f"upper bound {upper_bound}:")
# Out:
# 16
# lower bound -0.7312500000000011:
# upper bound 5.578750000000001:
# 19
# lower bound -0.1445901639344262:
# upper bound 0.3743169398907103:
# 11
# lower bound -0.4149999999999998:
# upper bound 3.8649999999999993:
# 5
# lower bound -0.16624999999999995:
# upper bound 1.2037499999999999:

# %%
# df = df[(df[col] > lower_bound) & (df[col] < upper_bound)]

# %%
number=df.select_dtypes(include=['number'])
number.corr()
# Out:
#                      total_sales  critic_score  north_america_sales  \
# total_sales             1.000000      0.232079             0.640467
# critic_score            0.232079      1.000000             0.207055
# north_america_sales     0.640467      0.207055             1.000000
# japan_sales             0.174955     -0.106555            -0.041333
# europe_sales            0.516474      0.014088            -0.296424
# other_sales             0.570794      0.212823            -0.028504
#
#                      japan_sales  europe_sales  other_sales
# total_sales             0.174955      0.516474     0.570794
# critic_score           -0.106555      0.014088     0.212823
# north_america_sales    -0.041333     -0.296424    -0.028504
# japan_sales             1.000000      0.194969     0.194474
# europe_sales            0.194969      1.000000     0.564220
# other_sales             0.194474      0.564220     1.000000

# %%
sns.heatmap(number.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.groupby(['Genre'])['total_sales'].mean().sort_values(ascending=False)
# Out:
# Genre
# Music               5.390000
# Action-Adventure    5.168000
# Role-Playing        5.036000
# Strategy            5.010000
# Racing              4.954444
# Shooter             4.777436
# Action              4.630256
# Misc                4.471333
# Simulation          4.313333
# Platform            4.206667
# Sports              4.148571
# Adventure           3.995000
# Fighting            3.503333
# Name: total_sales, dtype: float64

# %%
df.sort_values(by='total_sales', ascending=False).head(10)
# Out:
#                            title           publisher              developer  \
# 27   The Elder Scrolls V: Skyrim  Bethesda Softworks  Bethesda Game Studios
# 28            Grand Theft Auto V      Rockstar Games         Rockstar North
# 37    Call of Duty: World at War          Activision               Treyarch
# 38     Call of Duty: Black Ops 3          Activision               Treyarch
# 39                 Battlefield 3     Electronic Arts                   Dice
# 40                 Battlefield 1     Electronic Arts                EA DICE
# 41                 Battlefield 3     Electronic Arts                   Dice
# 42    Need for Speed Underground     Electronic Arts           EA Black Box
# 43  Need for Speed Underground 2     Electronic Arts           EA Black Box
# 44                  Just Dance 4             Ubisoft                Ubisoft
#
#            Genre consol  total_sales  critic_score  north_america_sales  \
# ...

# %%
df2= df.groupby('Genre')[['north_america_sales',
                          'japan_sales','europe_sales','other_sales','total_sales']].mean().sort_values(by="total_sales",ascending=False)
df2
# Out:
#                   north_america_sales  japan_sales  europe_sales  other_sales  \
# Genre
# Music                        2.980000     0.179727      1.935000     0.475000
# Action-Adventure             2.456000     0.121945      1.956000     0.674000
# Role-Playing                 2.777000     0.100973      1.617000     0.558000
# Strategy                     2.790000     0.179727      1.890000     0.330000
# Racing                       2.314444     0.107687      1.930000     0.665556
# Shooter                      2.497692     0.133270      1.618718     0.572051
# Action                       2.316667     0.095606      1.697692     0.542308
# Misc                         2.506000     0.129909      1.470000     0.425333
# Simulation                   2.120000     0.131530      1.810000     0.340000
# Platform                     1.975000     0.155000      1.535000     0.543333
# Sports                       1.770714     0.053919      1.811071     0.520714
# ...

# %%
df.columns
# Out:
# Index(['title', 'publisher', 'developer', 'Genre', 'consol', 'total_sales',
#        'critic_score', 'north_america_sales', 'japan_sales', 'europe_sales',
#        'other_sales'],
#       dtype='object')

# %%
sns.histplot(df['total_sales'], kde=True)
# Out:
# <Axes: xlabel='total_sales', ylabel='Count'>

# %%
sales_cols = ['north_america_sales', 'japan_sales', 'europe_sales','total_sales']
all_outlier_indices = set()

for col in sales_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]
    print(outliers.head())
    outlier_indices = set(outliers.index)
    all_outlier_indices = all_outlier_indices.union(outlier_indices)
# Out:
#                          title       publisher       developer    Genre  \
# 0           Grand Theft Auto V  Rockstar Games  Rockstar North   Action
# 1           Grand Theft Auto V  Rockstar Games  Rockstar North   Action
# 2  Grand Theft Auto: Vice City  Rockstar Games  Rockstar North   Action
# 3           Grand Theft Auto V  Rockstar Games  Rockstar North   Action
# 4    Call of Duty: Black Ops 3      Activision        Treyarch  Shooter
#
#   consol  total_sales  critic_score  north_america_sales  japan_sales  \
# 0    PS3        20.32         9.400                 6.37         0.99
# 1    PS4        19.39         9.700                 6.06         0.60
# 2    PS2        16.15         9.600                 8.41         0.47
# 3   X360        15.86         8.425                 9.06         0.06
# 4    PS4        15.09         8.100                 6.18         0.41
#
#    europe_sales  other_sales
# 0          9.85         3.12
# 1          9.71         3.02
# ...

# %%
outliers[['consol','Genre',"publisher"]].value_counts()
# Out:
# consol  Genre             publisher
# X360    Shooter           Activision         5
# PS3     Shooter           Activision         5
#         Action            Rockstar Games     2
# PS2     Action            Rockstar Games     2
# X360    Action            Rockstar Games     2
# PS4     Shooter           Activision         2
#         Action-Adventure  Rockstar Games     1
#         Action            Rockstar Games     1
#         Sports            Electronic Arts    1
#                           EA Sports          1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['title', 'publisher', 'developer', 'Genre', 'consol', 'total_sales',
#        'critic_score', 'north_america_sales', 'japan_sales', 'europe_sales',
#        'other_sales'],
#       dtype='object')

# %%
sales_cols = ['north_america_sales', 'japan_sales', 'europe_sales','total_sales']

grouped_sales = df.groupby('title')[sales_cols].sum().sort_values(by='total_sales', ascending=False)

print(grouped_sales.head(10))
# Out:
#                                 north_america_sales  japan_sales  \
# title
# Grand Theft Auto V                            26.19     1.660000
# Call of Duty: Modern Warfare 3                14.61     0.620000
# Call of Duty: Black Ops II                    13.26     0.720000
# Call of Duty: Black Ops                       15.77     0.590000
# Call of Duty: Ghosts                          12.66     0.480000
# Call of Duty: Modern Warfare 2                13.53     0.460000
# Call of Duty: Black Ops 3                     10.81     0.430000
# Grand Theft Auto IV                           11.59     0.580000
# Call of Duty: Advanced Warfare                10.49     0.350000
# Red Dead Redemption 2                          9.02     0.389727
#
#                                 europe_sales  total_sales
# title
# Grand Theft Auto V                     28.14        64.29
# Call of Duty: Modern Warfare 3         10.07        28.17
# Call of Duty: Black Ops II             10.20        27.66
# ...

# %%
top_publishers = df.groupby('publisher')['total_sales'].sum().sort_values(ascending=False).head(10)
top_publishers.plot(kind='bar', title='Top 10 Publishers by Total Sales')
# Out:
# <Axes: title={'center': 'Top 10 Publishers by Total Sales'}, xlabel='publisher'>
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
pivot = df.groupby(['consol', 'Genre'])['total_sales'].mean().unstack()
plt.figure(figsize=(12, 6))
sns.heatmap(pivot, annot=True, fmt=".2f", cmap="YlGnBu")

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
top10 = df.sort_values(by='total_sales', ascending=False).head(10)
top10.set_index('title')[['north_america_sales', 'japan_sales', 'europe_sales', 'other_sales']].plot(kind='bar', figsize=(15, 6))
plt.title("Top 10 Games Sales by Region")
# Out:
# Text(0.5, 1.0, 'Top 10 Games Sales by Region')
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
regions = ['north_america_sales', 'japan_sales', 'europe_sales', 'other_sales']
region_sales = df[regions].sum()

region_sales.plot.pie(autopct='%1.1f%%', figsize=(7,7), startangle=140)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
top_publishers = df.groupby('publisher')['total_sales'].sum().sort_values(ascending=False).head(5)

top_publishers.plot(kind='bar', color='skyblue', figsize=(10, 5))

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(
    data=df,
    y='Genre',  # خليه أفقي بدل عمودي عشان الأسماء الطويلة
    order=df['Genre'].value_counts().index,
    palette='Set2'
)

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...
